# %%
# Parameters
input_name = "Gemini User"
iteration = 99

# %%
# ช่องนี้คือช่องสำหรับรับ Parameters
input_name = "Guest"
iteration = 1

# %%
import datetime

now = datetime.datetime.now()
message = f"สวัสดีคุณ {input_name}, วันนี้วันที่ {now}. นี่คือรอบการรันที่ {iteration}"
print(message)
# Out:
# สวัสดีคุณ Guest, วันนี้วันที่ 2026-02-14 09:05:07.532414. นี่คือรอบการรันที่ 1

# %%
with open("test_output.txt", "a", encoding="utf-8") as f:
    f.write(message + "\n")
print("บันทึกไฟล์สำเร็จ!")
# Out:
# บันทึกไฟล์สำเร็จ!
